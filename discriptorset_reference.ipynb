# %%
import numpy as np

class Creat():
    def get_1(self, base):
        self.base=base
        self.num=1
    def get_2(self, base1, base2):
        self.base1=base1
        self.base2=base2
        self.num=2
    def abs_ad(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem='|'+self.base[i]+'+'+j+'|'
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem='|'+i+'+'+j+'|'
                    self.ans.append(self.tem)
        return self.ans
    def square(self):
        self.ans=[]
        for i in range(len(self.base)):
            self.tem=self.base[i]+'^2'
            self.ans.append(self.tem)
        return self.ans
    def expon(self):
        self.ans=[]
        for i in self.base:
            self.tem='exp('+i+r')'
            self.ans.append(self.tem)
        return self.ans
    def ratio(self):
        self.ans=[]
        for i in self.base1:
            for j in self.base2:
                self.tem=i+r'/'+j
                self.ans.append(self.tem)
        return self.ans
class Creat1():
    def get_1(self, base):
        self.base=base
        self.num=1
    def get_2(self, base1, base2):
        self.base1=base1
        self.base2=base2
        self.num=2
    def abs_ad(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem=abs(self.base[i]+j)
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem=abs(i+j)
                    self.ans.append(self.tem)
        return self.ans
     def abs_sb(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem=abs(self.base[i]-j)
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem=abs(i-j)
                    self.ans.append(self.tem)
        return self.ans
    def square(self):
        self.ans=[]
        for i in range(len(self.base)):
            self.tem=self.base[i]**2
            self.ans.append(self.tem)
        return self.ans
    def expon(self):
        self.ans=[]
        for i in self.base:
            self.tem=exp(i)
            self.ans.append(self.tem)
        return self.ans
    def ratio(self):
        self.ans=[]
        for i in self.base1:
            for j in self.base2:
                self.tem=i/j
                self.ans.append(self.tem)
        return self.ans
    
Class_A1=['IPA','IPB','EAA','EAB']
Class_A2=['HA','LA','HB','LB']
Class_A3=['rsA','rsB','rpA','rpB','rdA','rdB']
Generation=[]
creat=Creat()
gen=0
creat.get_1(Class_A1)
Generation.append(creat.abs_ad())
print(len(Generation[gen]))
print(Generation[gen])
creat.get_1(Class_A2)
gen=gen+1
Generation.append(creat.abs_ad())
creat.get_1(Class_A3)
gen=gen+1
Generation.append(creat.abs_ad())
print(len(Generation[gen]))
creat.get_1(Class_A3)
Generation.append(creat.square())
gen=gen+1
creat.get_1(Generation[2])
Generation[gen].extend(creat.square())
print(len(Generation[gen]))
creat.get_1(Class_A3)
Generation.append(creat.expon())
gen=gen+1
creat.get_1(Generation[2])
Generation[gen].extend(creat.expon())
print(len(Generation[gen]))
creat.get_1(Generation[3])
gen=gen+1
Generation.append(creat.expon())
print(len(Generation[gen]))
# Out:
# 6
# ['|IPA+IPB|', '|IPA+EAA|', '|IPA+EAB|', '|IPB+EAA|', '|IPB+EAB|', '|EAA+EAB|']
# 15
# 21
# 21
# 21

# %%
a=[[1,2],[2,2]]
print(a[0][1])
# Out:
# 2

# %%
class Creat():
    def get_1(self, base):
        self.base=base
        self.num=1
    def get_2(self, base1, base2):
        self.base1=base1
        self.base2=base2
        self.num=2
    def abs_ad(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem='|'+self.base[i]+'+'+j+'|'
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem='|'+i+'+'+j+'|'
                    self.ans.append(self.tem)
        return self.ans
    def abs_sb(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem='|'+self.base[i]+'-'+j+'|'
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem='|'+i+'-'+j+'|'
                    self.ans.append(self.tem)
        return self.ans
    def square(self):
        self.ans=[]
        for i in range(len(self.base)):
            self.tem=self.base[i]+'^2'
            self.ans.append(self.tem)
        return self.ans
    def expon(self):
        self.ans=[]
        for i in self.base:
            self.tem='exp('+i+r')'
            self.ans.append(self.tem)
        return self.ans
    def ratio(self):
        self.ans=[]
        for i in self.base1:
            for j in self.base2:
                self.tem=i+r'/'+j
                self.ans.append(self.tem)
        return self.ans
class Creat1():
    def get_1(self, base):
        self.base=base
        self.num=1
    def get_2(self, base1, base2):
        self.base1=base1
        self.base2=base2
        self.num=2
    def abs_ad(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem=abs(self.base[i]+j)
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem=abs(i+j)
                    self.ans.append(self.tem)
        return self.ans
    def abs_sb(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem=abs(self.base[i]-j)
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem=abs(i-j)
                    self.ans.append(self.tem)
        return self.ans
    def square(self):
        self.ans=[]
        for i in range(len(self.base)):
            self.tem=self.base[i]**2
            self.ans.append(self.tem)
        return self.ans
    def expon(self):
        self.ans=[]
        for i in self.base:
            self.tem=exp(i)
            self.ans.append(self.tem)
        return self.ans
    def ratio(self):
        self.ans=[]
        for i in self.base1:
            for j in self.base2:
                self.tem=i/j
                self.ans.append(self.tem)
        return self.ans
    
Class_A1=['IPA','IPB','EAA','EAB']
Class_A2=['HA','LA','HB','LB']
Class_A3=['rsA','rsB','rpA','rpB','rdA','rdB']
Generation=[]
creat=Creat()
creat.get_1(Class_A1)
Generation.append(creat.abs_ad())
print(len(Generation[0]))
creat.get_1(Class_A2)  #mark
Generation.append(creat.abs_ad())
print(len(Generation[1]))  #              G1
creat.get_1(Class_A3)
Generation.append(creat.abs_ad())
print(len(Generation[2]))
Generation.append(creat.square())
Generation.append(creat.expon())
creat.get_1(Generation[2])
Generation[3].extend(creat.square())
Generation[4].extend(creat.expon())
print(len(Generation[3]))
print(len(Generation[4]))
creat.get_1(Generation[3])
Generation.append(creat.expon())     #gen=5
print(len(Generation[5]))
creat.get_1(Class_A1)
Generation[0].extend(creat.abs_sb())
creat.get_1(Class_A2)
Generation[1].extend(creat.abs_sb())
creat.get_1(Class_A3)
Generation[2].extend(creat.abs_sb())
creat.get_1(Generation[0])
Generation.append(creat.abs_ad())
Generation[6].extend(creat.abs_sb())     #gen=6
print(len(Generation[6]))
creat.get_1(Generation[1])
Generation.append(creat.abs_ad())
Generation[7].extend(creat.abs_sb())     #gen=7
print(len(Generation[7]))
creat.get_1(Generation[2])
Generation.append(creat.abs_ad())
Generation[8].extend(creat.abs_sb())     #gen=8
#print(len(Generation[8]))
creat.get_2(Class_A1,Class_A3)
Generation.append(creat.ratio())
creat.get_2(Class_A2,Class_A3)
Generation.append(creat.ratio())
creat.get_2(Generation[0],Class_A3)
Generation.append(creat.ratio())
creat.get_2(Generation[1],Class_A3)
Generation.append(creat.ratio())
creat.get_2(Generation[2],Class_A3)
Generation.append(creat.ratio())
creat.get_2(Class_A1,Generation[3])    
Generation.append(creat.ratio())
creat.get_2(Class_A2,Generation[3])
Generation.append(creat.ratio())
creat.get_2(Class_A3,Generation[3])
Generation.append(creat.ratio())
creat.get_2(Generation[0],Generation[3])
Generation.append(creat.ratio())
creat.get_2(Generation[1],Generation[3])
Generation.append(creat.ratio())
creat.get_2(Generation[2],Generation[3])
Generation.append(creat.ratio())
creat.get_2(Class_A1,Generation[4])
Generation.append(creat.ratio())
creat.get_2(Class_A2,Generation[4])
Generation.append(creat.ratio())
creat.get_2(Class_A3,Generation[4])
Generation.append(creat.ratio())
creat.get_2(Generation[0],Generation[4])
Generation.append(creat.ratio())
creat.get_2(Generation[1],Generation[4])
Generation.append(creat.ratio())
creat.get_2(Generation[2],Generation[4])
Generation.append(creat.ratio())
creat.get_2(Class_A1,Generation[5])
Generation.append(creat.ratio())
creat.get_2(Class_A2,Generation[5])
Generation.append(creat.ratio())
creat.get_2(Class_A3,Generation[5])
Generation.append(creat.ratio())
creat.get_2(Generation[0],Generation[5])
Generation.append(creat.ratio())
creat.get_2(Generation[1],Generation[5])
Generation.append(creat.ratio())
creat.get_2(Generation[2],Generation[5])
Generation.append(creat.ratio())
print(len(Generation))
kk=Class_A1
kk.extend(Class_A2)
kk.extend(Class_A3)
for i in Generation:
    kk.extend(i)
for i in range(len(kk)):
    if kk[i]=='|IPB-EAB|/rpA^2':
        print(i)
print(kk[1660])
print(kk[4220])
print(len(kk))
# Out:
# 6
# 6
# 15
# 21
# 21
# 21
# 132
# 132
# 32
# 2143
# IPB/rpA^2
# |rsA-rpB|/exp(rsA)
# 5921

# %%
class Creat():
    def get_1(self, base):
        self.base=base
        self.num=1
    def get_2(self, base1, base2):
        self.base1=base1
        self.base2=base2
        self.num=2
    def abs_ad(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem='|'+self.base[i]+'+'+j+'|'
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem='|'+i+'+'+j+'|'
                    self.ans.append(self.tem)
        return self.ans
    def abs_sb(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem='|'+self.base[i]+'-'+j+'|'
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem='|'+i+'-'+j+'|'
                    self.ans.append(self.tem)
        return self.ans
    def square(self):
        self.ans=[]
        for i in range(len(self.base)):
            self.tem=self.base[i]+'^2'
            self.ans.append(self.tem)
        return self.ans
    def expon(self):
        self.ans=[]
        for i in self.base:
            self.tem='exp('+i+r')'
            self.ans.append(self.tem)
        return self.ans
    def ratio(self):
        self.ans=[]
        for i in self.base1:
            for j in self.base2:
                self.tem=i+r'/'+j
                self.ans.append(self.tem)
        return self.ans
class Creat1():
    def get_1(self, base):
        self.base=base
        self.num=1
    def get_2(self, base1, base2):
        self.base1=base1
        self.base2=base2
        self.num=2
    def abs_ad(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem=abs(self.base[i]+j)
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem=abs(i+j)
                    self.ans.append(self.tem)
        return self.ans
    def abs_sb(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem=abs(self.base[i]-j)
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem=abs(i-j)
                    self.ans.append(self.tem)
        return self.ans
    def square(self):
        self.ans=[]
        for i in range(len(self.base)):
            self.tem=self.base[i]**2
            self.ans.append(self.tem)
        return self.ans
    def expon(self):
        self.ans=[]
        for i in self.base:
            self.tem=exp(i)
            self.ans.append(self.tem)
        return self.ans
    def ratio(self):
        self.ans=[]
        for i in self.base1:
            for j in self.base2:
                self.tem=i/j
                self.ans.append(self.tem)
        return self.ans
    
Class_A1=['IPA','IPB','EAA','EAB']
Class_A2=['HA','LA','HB','LB']
Class_A3=['rsA','rsB','rpA','rpB','rdA','rdB']
Generation=[]
creat=Creat()
creat.get_1(Class_A1)
Generation.append(creat.abs_ad())
#print(len(Generation[0]))
creat.get_1(Class_A2)  #mark
Generation.append(creat.abs_ad())
#print(len(Generation[1]))  #              G1
creat.get_1(Class_A3)
Generation.append(creat.abs_ad())
#print(len(Generation[2]))
Generation.append(creat.square())
Generation.append(creat.expon())
creat.get_1(Generation[2])
Generation[3].extend(creat.square())
Generation[4].extend(creat.expon())
#print(len(Generation[3]))
#print(len(Generation[4]))
creat.get_1(Generation[3])
Generation.append(creat.expon())     #gen=5
#print(len(Generation[5]))
creat.get_1(Class_A1)
Generation[0].extend(creat.abs_sb())
creat.get_1(Class_A2)
Generation[1].extend(creat.abs_sb())
creat.get_1(Class_A3)
Generation[2].extend(creat.abs_sb())
creat.get_1(Generation[0])
Generation.append(creat.abs_ad())
Generation[6].extend(creat.abs_sb())     #gen=6
#print(len(Generation[6]))
creat.get_1(Generation[1])
Generation.append(creat.abs_ad())
Generation[7].extend(creat.abs_sb())     #gen=7
creat.get_1(Generation[2])
Generation.append(creat.abs_ad())
Generation[8].extend(creat.abs_sb())     #gen=8
#print(len(Generation[8]))
creat.get_2(Class_A1,Class_A3)
Generation.append(creat.ratio())
creat.get_2(Class_A2,Class_A3)
Generation.append(creat.ratio())
creat.get_2(Generation[0],Class_A3)
Generation.append(creat.ratio())
creat.get_2(Generation[1],Class_A3)
Generation.append(creat.ratio())
creat.get_2(Generation[2],Class_A3)
Generation.append(creat.ratio())
creat.get_2(Class_A1,Generation[3])    
Generation.append(creat.ratio())
creat.get_2(Class_A2,Generation[3])
Generation.append(creat.ratio())
creat.get_2(Class_A3,Generation[3])
Generation.append(creat.ratio())
creat.get_2(Generation[0],Generation[3])
Generation.append(creat.ratio())
creat.get_2(Generation[1],Generation[3])
Generation.append(creat.ratio())
creat.get_2(Generation[2],Generation[3])
Generation.append(creat.ratio())
creat.get_2(Class_A1,Generation[4])
Generation.append(creat.ratio())
creat.get_2(Class_A2,Generation[4])
Generation.append(creat.ratio())
creat.get_2(Class_A3,Generation[4])
Generation.append(creat.ratio())
creat.get_2(Generation[0],Generation[4])
Generation.append(creat.ratio())
creat.get_2(Generation[1],Generation[4])
Generation.append(creat.ratio())
creat.get_2(Generation[2],Generation[4])
Generation.append(creat.ratio())
creat.get_2(Class_A1,Generation[5])
Generation.append(creat.ratio())
creat.get_2(Class_A2,Generation[5])
Generation.append(creat.ratio())
creat.get_2(Class_A3,Generation[5])
Generation.append(creat.ratio())
creat.get_2(Generation[0],Generation[5])
Generation.append(creat.ratio())
creat.get_2(Generation[1],Generation[5])
Generation.append(creat.ratio())
creat.get_2(Generation[2],Generation[5])
Generation.append(creat.ratio())
print(len(Generation))
kk=Class_A1
kk.extend(Class_A3)
for j in range(len(Generation)):
    if (j!=1)and(j!=7)and(j!=10)and(j!=12)and(j!=15)and(j!=18)and(j!=21)and(j!=24)and(j!=30)and(j!=27):
        kk.extend(Generation[j])
for i in range(len(kk)):
    if kk[i]=='|IPB-EAB|/rpA^2':
        print(i)
print(kk[1668])
print(kk[3304])
print(len(kk))
# Out:
# 32
# 1815
# |IPB+EAA|/rpA^2
# |rsA-rpB|/exp(rsA)
# 4669

# %%
class Creat():
    def get_1(self, base):
        self.base=base
        self.num=1
    def get_2(self, base1, base2):
        self.base1=base1
        self.base2=base2
        self.num=2
    def abs_ad(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem='|'+self.base[i]+'+'+j+'|'
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem='|'+i+'+'+j+'|'
                    self.ans.append(self.tem)
        return self.ans
    def abs_sb(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)-1):
                for j in self.base[i+1:]:
                    self.tem='|'+self.base[i]+'-'+j+'|'
                    self.ans.append(self.tem)
        else:
            for i in self.base1:
                for j in self.base2:
                    self.tem='|'+i+'-'+j+'|'
                    self.ans.append(self.tem)
        return self.ans
    def square(self):
        self.ans=[]
        for i in range(len(self.base)):
            self.tem=self.base[i]+'^2'
            self.ans.append(self.tem)
        return self.ans
    def expon(self):
        self.ans=[]
        for i in self.base:
            self.tem='exp('+i+r')'
            self.ans.append(self.tem)
        return self.ans
    def ratio(self):
        self.ans=[]
        if self.num==1:
            for i in range(len(self.base)):
                for j in range(len(self.base)):
                    if(i!=j):
                        self.tem=self.base[i]+r'/'+self.base[j]
                        self.ans.append(self.tem)
        if self.num==2:
            for i in self.base1:
                for j in self.base2:
                    self.tem=i+r'/'+j
                    self.ans.append(self.tem)
        return self.ans
A1=['eamax','enmax','ipmax']
A2=['eamin','enmin','ipmin']
A3=['a','b','c','dsq','dv']
A4=['rmax','rmin']
Generation=[]
creat=Creat()
#手动产生新特征
creat.get_1(A1)
Generation.append(creat.abs_ad()) #0
creat.get_1(A2)
Generation.append(creat.abs_ad()) #1
creat.get_1(A3)
Generation.append(creat.abs_ad()) #2
creat.get_1(A4)
Generation.append(creat.abs_ad()) #3
creat.get_1(A1)
Generation[0].extend(creat.abs_sb())
creat.get_1(A2)
Generation[1].extend(creat.abs_sb())
creat.get_1(A3)
Generation[2].extend(creat.abs_sb())
creat.get_1(A4)
Generation[3].extend(creat.abs_sb())
creat.get_1(A1)
Generation.append(creat.ratio())
creat.get_1(A2)
Generation.append(creat.ratio()) #5
creat.get_1(A3)
Generation.append(creat.ratio()) #6
creat.get_1(A4)
Generation.append(creat.ratio()) #7
creat.get_2(A1,A2)
Generation.append(creat.ratio()) #8
creat.get_2(A1,A3)
Generation.append(creat.ratio()) #9
creat.get_2(A1,A4)
Generation.append(creat.ratio()) #10
creat.get_2(A2,A3)
Generation.append(creat.ratio()) #11
creat.get_2(A2,A4)
Generation.append(creat.ratio()) #12
creat.get_2(A3,A4)
Generation.append(creat.ratio()) #13
Dpt1=A1
Dpt1.extend(A2)
Dpt1.extend(A3)
Dpt1.extend(A4)
print(len(Dpt1))
for j in Generation:
    Dpt1.extend(j)
for i in range(len(Dpt1)):
    if Dpt1[i]=='dsq/dv':
        print(i)
print(Dpt1[119])
print(len(Dpt1))
# Out:
# 13
# 74
# enmin/dsq
# 142
